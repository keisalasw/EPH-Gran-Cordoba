# %% [markdown]
# <a href="https://colab.research.google.com/github/keisalasw/EPH-Gran-Cordoba/blob/main/EPH.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
print("Encuesta Permanente de Hogares - UTN")
# Out:
# Encuesta Permanente de Hogares - UTN
