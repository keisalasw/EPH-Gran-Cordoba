# %% [markdown]
# <a href="https://colab.research.google.com/github/keisalasw/EPH-Gran-Cordoba/blob/main/EPH_Gran_Cordoba.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
print("Encuesta permanente de hogares")
# Out:
# Encuesta permanente de hogares
